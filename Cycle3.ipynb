# %%
 
#1,factorial
n=int(input("enter any number : "))
fact=1
i=1
while i<=n:
    fact=fact*i
    i=i+1
print("factorial of",n,"is",fact)
# Out:
# enter any number : 3
# factorial of 3 is 6

# %%
 
#2,Fibonacci
 
n=int(input("enter the value of n : "))
a=0
b=1
sum=0
count=1
print("fibonacci series : ")
while (count<=n):
  print(sum,end=" ")
  count+=1
  a=b
  b=sum
  sum=a+b
# Out:
# enter the value of n : 5
# fibonacci series :
# 0 1 1 2 3

# %%
 
#3,sum of items 
list1= [10,20,30,40,50]
print("The list is : " , list1)
sum = 0 
for x in range(0, len(list1)):
    sum = sum + list1[x]
print("Sum of all elements in the given list : ", sum)
# Out:
# The list is :  [10, 20, 30, 40, 50]
# Sum of all elements in the given list :  150

# %%
 #4
for i in range(1000,10000):
  for j in range(32,100):
    if i==j*j:
      a=str(i)
      if (int(a[0])%2==0 and int(a[1])%2==0 and int(a[2])%2==0 and int(a[3])%2==0):
        print(i)
# Out:
# 4624
# 6084
# 6400
# 8464

# %%
 
#5,pyramid
 
def py(n):
  x=1
  for i in range(1, n+1):
    for j in range(1, i+1):
      print(x, end=" ")
      x=x+i
    x=i+1
    print("\r")
 
n=int(input("enter the limit : "))
py(n)
# Out:
# enter the limit : 5
# 1
# 2 4
# 3 6 9
# 4 8 12 16
# 5 10 15 20 25

# %%
 
#6,character frequency
 
def freq(s):
  s=s.lower()
  dict={}
  for ch in s :
    keys = dict.keys()
    if ch in keys :
      dict[ch]+=1
    else:
      dict[ch]=1
  return dict
s=input("enter any string : ")
print("the character frequency of the given string",s,"are :")
print(freq(s))
# Out:
# enter any string : SamJohn vj
# the character frequency of the given string SamJohn vj are :
# {'s': 1, 'a': 1, 'm': 1, 'j': 2, 'o': 1, 'h': 1, 'n': 1, ' ': 1, 'v': 1}

# %%
 
#7,Add ‘ing’or'ly'
 
s=input("enter any string : ")
if s.endswith("ing") :
  s+="ly"
else :
  s+="ing"
print("modified string : ",s)
# Out:
# enter any string : SamJohn
# modified string :  SamJohning

# %%
 #8,length of longest word. 
 
l=[]
n= int(input("enter the number of elements in list : "))
for i in range(1,n+1):
    x=input()
    l.append(x)
max=len(l[0])
temp=l[0]
for j in l:
    if(len(j)>max):
       max=len(j)
       temp=j
print("the word with the longest length is :",temp)
print ("length:",len(temp))
# Out:
# enter the number of elements in list : 2
# Sam
# SamJohn
# the word with the longest length is : SamJohn
# length: 7

# %%
 
#9
 
# * 
# * * 
# * * * 
# * * * * 
# * * * * *
# * * * *
# * * * 
# * *
# * 
 
for i in range(5):
  for j in range(i+1):
    print("* ",end="")
  print()
for i in range(4):
  for j in range(i, 4):
    print("* ",end="")
  print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
 
#10,factors of a number
 
n=int(input("enter any number : "))
i=1
print("all factors of",n,"are :")
while i<=n:
  if n%i==0:
    print(i)
  i=i+1
# Out:
# enter any number : 20
# all factors of 20 are :
# 1
# 2
# 4
# 5
# 10
# 20

# %%
 
#11,lambda functions
 
a=int(input("enter the side of square : "))
sq_area=lambda a:a**2
print("area of the square is : ",sq_area(a))
l=int(input("enter length : "))
w=int(input("enter width : "))
rect_area=lambda l,w : l*w
print("area of the rectangle is : ",rect_area(l,w))
a=int(input("enter the value of first side : "))
b=int(input("enter the value of second side : "))
c=int(input("enter the value of third side : "))
s=(a+b+c)/2
t_area=lambda s,a,b,c : (s*(s-a)*(s-b)*(s-c))**0.5
print("area of triangle :",t_area(s,a,b,c))
# Out:
# enter the side of square : 2
# area of the square is :  4
# enter length : 4
# enter width : 5
# area of the rectangle is :  20
# enter the value of first side : 2
# enter the value of second side : 3
# enter the value of third side : 4
# area of triangle : 2.9047375096555625
