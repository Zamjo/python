# %%
#1
n=input("Enter house name: ")
s=input("Enter street name: ")
p=input("Enter pin-code: ")
print("Address:\n"+ n +"(H)\n"+ s +"\n"+p)
# Out:
# Enter house name: varoor
# Enter street name: south pampady
# Enter pin-code: 686521
# Address:
# varoor(H)
# south pampady
# 686521

# %%
#2
a=int(input("enter starting year: "))
b=int(input("enter ending year: "))
print("leap years between",a,"and",b)
while (a<=b):
    if ((a%400==0) or ((a%4==0) and (a%100!=0))):
      print(a)
    a=a+1
# Out:
# enter starting year: 2021
# enter ending year: 2030
# leap years between 2021 and 2030
# 2024
# 2028

# %%
#3a
l = [-1, -2, -4, 4, -6, 3]
p=[num for num in l if num > 0] 
print("Positive numbers in the list: ", *p)
# Out:
# Positive numbers in the list:  4 3

# %%
#3b 
n = [1, 2, 3, 4, 5]
square = [num ** 2 for num in num]
print(square)
# Out:
# [1, 4, 9, 16, 25]

# %%
#3c
a=input("enter a word : ")
b=[c for c in a if c in 'aeiou']
print("list of vowels in",a,":",b)
# Out:
# enter a word : Samjohn
# list of vowels in Samjohn : ['a', 'o']

# %%
#3d
w=input("enter any word : ")
for i in range(len(w)) :
  print("ASCII value of",w[i],":",ord(w[i]))
# Out:
# enter any word : sam
# ASCII value of s : 115
# ASCII value of a : 97
# ASCII value of m : 109

# %%
#4
def word_count(str):
    counts = dict()
    words = str.split()
    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1
    return counts
str=input("enter any text :")
print(word_count(str))
# Out:
# enter any text :men will be men
# {'men': 2, 'will': 1, 'be': 1}

# %%
#5
x=[]
 n=int(input("enter any integers :"))
for i in range(1,n+1):
  a=int(input())
  if (a>100):
    x.append('over')
  else:
    x.append(a)
print("modified list :" ,x)
# Out:
# enter any integers :3
# 409
# 6
# 99
# modified list : ['over', 6, 99]

# %%
#6
a=input("Enter a word: ")
#a = ['sam', 'john']
b = a.count('a')
print('the count of a is',b)
# Out:
# Enter a word: sam
# the count of a is 1

# %%
#7a
a=len([1,2])
b=len([1,2,3])
if a == b:
 print ('same length')
else:
 print ('not same')
# Out:
# not same

# %%
#7b
a=[1,2,3]
b=[2,3]
c=sum(a)
d=sum(b)
if c==d:
 print ('same value')
else:
 print ('not same')
# Out:
# not same

# %%
#7c
a=[1,2,3]
b=[2,3]
print(set(a).intersection (b))
# Out:
# {2, 3}

# %%
#8
str=input("enter a string : ")
def replace_ch(str1):
  char=str1[0]
  str1=str1.replace(char, '$')
  str1=char+str1[1:]
  return str1
print(replace_ch(str))
# Out:
# enter a string : ADIDAS
# ADID$S

# %%
#9
def change(str):
      return str[-1:] + str[1:-1] + str[:1]
str=input("enter any string : ")
print("modified string : ",change(str))
# Out:
# enter any string : Python
# modified string :  nythoP

# %%
#10
r=int(input("enter the radius of the circle :"))
print("area of the circle is :",3.14*r*r)
# Out:
# enter the radius of the circle :1
# area of the circle is : 3.14

# %%
 #11
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: ")) 
if (a > b) and (a > c):
   largest = a
elif (b > a) and (b > c):
   largest = b
else:   largest = c
print("The largest number is",largest)
# Out:
# Enter first number: 1
# Enter second number: 4
# Enter third number: 2
# The largest number is 4.0

# %%
#12
a=input("enter any filename : ")
x=a.split(".")
print("extension of file is",x[-1])
# Out:
# enter any filename : Sample.py
# extension of file is py

# %%
#13
c=[]
x=int(input("enter limit for list : "))
for i in range(1,x+1):
  a=input()
  c.append(a)
print(c)
print(c[0],c[-1])
# Out:
# enter limit for list : 3
# Red
# Blue
# Green
# ['Red', 'Blue', 'Green']
# Red Green

# %%
#14
a=int(input("enter any integer : "))
n1=int("%s" %a)
n2=int("%s%s" %(a,a))
n3=int("%s%s%s" %(a,a,a))
print("value of n+nn+nnn is : ",n1+n2+n3)
# Out:
# enter any integer : 1
# value of n+nn+nnn is :  123

# %%
#15
c1=[]
x=int(input("enter limit for list1 :"))
for i in range(1,x+1):
  a=input()
  c1.append(a)
  p=set(c1)
print(p)
c2=[]
y=int(input("enter limit for list2 : "))
for i in range(1,y+1):
  b=input()
  c2.append(b)
  q=set(c2)
print(q)
print(p.difference(q))
# Out:
# enter limit for list1 :3
# Green
# White
# Red
# {'White', 'Red', 'Green'}
# enter limit for list2 : 3
# Blue
# White
# Green
# {'White', 'Green', 'Blue'}
# {'Red'}

# %%
#16
x=input("enter the first string : ")
y=input("enter the second string : ")
def swapch(x,y): 
  a = y[:1] + x[1:]
  b = x[:1] + y[1:]
  return a + ' ' + b
print(swapch(x,y))
# Out:
# enter the first string : Sam
# enter the second string : John
# Jam Sohn

# %%
#17
k1=input("enter first key : ")
k2=input("enter second key : ")
k3=input("enter third key : ")
k4=input("enter fourth key : ")
k5=input("enter fifth key : ")
v1=input("enter first value : ")
v2=input("enter second value : ")
v3=input("enter third value : ")
v4=input("enter fourth value : ")
v5=input("enter fifth value : ")
d={}
d[k1]=v1
d[k2]=v2
d[k3]=v3
d[k4]=v4
d[k5]=v5
l=list(d.items())   
l.sort() 
print("ascending order is : ",l)
l=list(d.items())
l.sort(reverse = True)
print("descending order is : ",l)
# Out:
# enter first key : 1
# enter second key : 4
# enter third key : 5
# enter fourth key : 2
# enter fifth key : 3
# enter first value : Red
# enter second value : Green
# enter third value : Blue
# enter fourth value : White
# enter fifth value : Black
# ascending order is :  [('1', 'Red'), ('2', 'White'), ('3', 'Black'), ('4', 'Green'), ('5', 'Blue')]
# descending order is :  [('5', 'Blue'), ('4', 'Green'), ('3', 'Black'), ('2', 'White'), ('1', 'Red')]

# %%
#18
k1=input("enter first key : ")
k2=input("enter second key : ")
v1=input("enter first value : ")
v2=input("enter second value : ")
dict1={}
dict2={}
dict1[k1]=v1
dict2[k2]=v2
def merge_dictionaries(x,y):
  z = {**x,**y}
  print("merged dictionary is : ")
  return z
print(merge_dictionaries(dict1,dict2))
# Out:
# enter first key : 2
# enter second key : 1
# enter first value : Red
# enter second value : Blue
# merged dictionary is :
# {'2': 'Red', '1': 'Blue'}

# %%
#19
n1=float(input("enter the first value : "))
n2=float(input("enter the second value : "))
x=n1
y=n2
while (n2 != 0):
  temp=n2
  n2=n1%n2
  n1=temp
gcd=n1   
print("GCD of",x,"and",y,"is",gcd)
# Out:
# enter the first value : 18
# enter the second value : 84
# GCD of 18.0 and 84.0 is 6.0

# %%
#20
x=[]
n=int(input("enter limit : "))
for i in range(1,n+1):
    a=int(input("enter the value of %d item : "%i))
    x.append(a)
for i  in x:
  if (i%2 == 0):
    x.remove(i)
print("modified list after removing even numbers :")
print(x)
# Out:
# enter limit : 3
# enter the value of 1 item : 23
# enter the value of 2 item : 42
# enter the value of 3 item : 5
# modified list after removing even numbers :
# [23, 5]
